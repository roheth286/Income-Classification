# %% [markdown]
# # Income Classification ML Pipeline
#
# This notebook runs each stage of the Income Classification machine learning pipeline sequentially from helper scripts under `src/` using the `%run` magic command.

# %%
# Stage 1: Load and clean raw dataset
# %run ../src/data_cleaning.py

# %%
# Stage 2: Feature encoding and splitting data
# %run ../src/feature_encoding.py

# %%
# Stage 3: Train Logistic Regression, Random Forest, and SVM models
# %run ../src/model_training.py

# %%
# Stage 4: Evaluate performance and plot ROC curve
# %run ../src/model_evaluation.py
